# %%
import boto3

# %%
##code from here

# %%
doc = []
# Document
documentName = "person2.jpg"

# Read document content
with open(documentName, 'rb') as document:
    imageBytes = bytearray(document.read())

# Amazon Textract client
textract = boto3.client('textract')

# Call Amazon Textract
response = textract.detect_document_text(Document={'Bytes': imageBytes})

#print(response)

# Print detected text
for item in response["Blocks"]:
    if item["BlockType"] == "WORD": #LINE for full line
        print (item["Text"])
        doc.append(item["Text"])
# Out:
# FORERKORT
# FORARKORT
# NORGE
# N
# NOREG
# 1.
# NORDMANN
# 2.
# KARI
# 3.
# 16.10.1972
# -
# 4a.
# 01.09.2018
# 4c.
# STATENS
# VEGVESEN
# 4b.
# 01.09.2033
# 4d.
# 16107212345
# 5.
# 05 18 123456
# 1
# 2713
# 7.
# kan
# NORD
# MANNKARINORD
# MANNKARINORD
# MANNKARINOR
# 9.
# ABEC1ES
# T
# CION
# DRIVING
# LICENCE
# FUHRERSCHEIN
# PERMIS
# DE
# CONDUIRE
# PATENTE
# DI
# GUIDA
# PERMISO
# DE
# CONDUCCION
# DRIVING
# DE
# CONDUCAO
# PRAWO
# JAZDY
# PERMIS
# DE
# CONDUCERE
# RIJBEWIJS
# VEZETOI
# ENGEDELY
# CARTA
# DE
# CONDUCAO
# PRAWO
# Z
# AAEIA
# KORKORT
# RIDICSKY
# PRUKAZ
# 3A
# HA
# MNC
# VODICSKY
# PREUKAZ
# AAEIA
# VOLJENJE
# KOREKORT
# AJOKORTTI
# VOZACKA
# DOZVOLA
# VAIRUOTOJO
# PAZYMEJIMAS
# VOZNISKO
# DOVOLIENJE
# KOREKOR
# ENZJA
# TAS-SEWQAN
# JUHILUBA
# CEADUAS
# TIOMANA
# VADITAJAAPLIECIBA
# LICENZJA
# TAS-SEWOAN
# EOS-MODELL
# JUHILUB

# %%
##empty dictony that wii store information
information = {}
for i in doc:
    if i=='1.' or i =='1':
        index = doc.index(i) # index will check the index of char in list
        information.update({'1.': doc[index+1]})
    elif i == '2.' or i == '2':
        index = doc.index(i)
        information.update({'2.': doc[index+1]})       
    elif i == '3.' or i == '3':
        index = doc.index(i)
        information.update({'3.': doc[index+1]})
    elif i == '4a.' or i == '4a':
        index = doc.index(i)
        information.update({'4a.': doc[index+1]})
    elif i == '4b.' or i == '4b':
        index = doc.index(i)
        information.update({'4b.': doc[index+1]})
    elif i == '4c.' or i == '4c':
        index = doc.index(i)
        information.update({'4c.': doc[index+1]})
    elif i == '4d.' or i == '4d':
        index = doc.index(i)
        information.update({'4d.': doc[index+1]})
    elif i == '5.' or i == '5':
        index = doc.index(i)
        information.update({'5.': doc[index+1]})

# %%
information
# Out:
# {'1.': '2713',
#  '2.': 'KARI',
#  '3.': '16.10.1972',
#  '4a.': '01.09.2018',
#  '4c.': 'STATENS',
#  '4b.': '01.09.2033',
#  '4d.': '16107212345',
#  '5.': '05 18 123456'}

# %%
# # Open the file in write mode
# with open('person5.txt', 'w') as file:
#     file.write(information)

# %%
# try:
#     index = doc.index('1.' or '1')
#     print(doc[index+1])
# except ValueError:
#     print("'orange' was not found in the list")

# s3 = boto3.resource(service_name='s3', 
#                     region_name='us-west-2',
#                     aws_access_key_id='AKIAY4GAOHISD5N4XHWP',
#                     aws_secret_access_key='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')

# keys = ['1.','2.','3.','4a.','4b.','4c.','4d.','5.']
# pairs=[]

# for i in keys:
#     index = doc.index(i)
#     #print(doc[index+1])
#     pairs.append(doc[index+1])

# for i in range(8):
#     print(keys[i]+':'+pairs[i])

# # Open the file in write mode
# with open('person5.txt', 'w') as file:
#     for i in range(8):
#         file.write(keys[i]+':'+pairs[i]+'\n')

#pip freeze> req.txt
